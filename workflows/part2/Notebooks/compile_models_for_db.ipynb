# %%
import pandas as pd
import numpy as np
import yaml
import os
import sys
# Get the current working directory
working_dir = '/arc/project/st-ashapi01-1/git/afraz96/RADD/workflows/part2_version2'
sys.path.append(working_dir)
import train
import test
# Append the src directory to the Python path
src_dir = os.path.join(working_dir, 'src')
sys.path.append(src_dir)

# Path to the config file
config_path = os.path.join(working_dir, 'config', 'config.yaml')
import utils

with open(config_path) as f:
    config = yaml.load(f, Loader=yaml.FullLoader)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PowerTransformer
from sklearn.decomposition import PCA
import logging
import pickle
from sklearn import preprocessing
import math
import time
# Import the ML Models
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb
import xgboost
from tensorflow.keras.models import Sequential, model_from_json
import tensorflow as tf
# Out:
# 2024-10-02 09:17:46.253867: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 09:17:47.678564: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-02 09:17:47.682042: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-02 09:17:53.154339: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Load in the models and check the compounds they predict on

# %%
high_res_data = pd.read_csv(os.path.join(working_dir, 'Data/NEW_HIGH_RES_2023_SMILES.csv'))
x500r_data = pd.read_csv(os.path.join(working_dir, 'Data/NEW_X500R_SMILES.csv'))
bccdc_data = pd.read_csv(os.path.join(working_dir, 'Data/training_data_bccdc_20240708.csv'))

# %% [markdown]
# # Load the ML models trained and the preprocessors

# %%
ml_models_dir = '/scratch/st-ashapi01-1/RADD/SMILES_ML_PIPELINE'
bccdc_output_dir = 'NPS_OUTPUT'
x500r_output_dir = 'X500R_OUTPUT'

# %%
def read_ml_models(directory):
    all_models = []
    for root, dirs, files in os.walk(os.path.join(directory, 'models')):
        for file in files:
            if file.endswith('.json'):
                    json_file = open(root + '/' + file, 'r')
                    loaded_model_json = json_file.read()
                    loaded_model = model_from_json(loaded_model_json)
                    all_models.append(loaded_model)
                    json_file.close() 
            elif file.endswith('.pkl'):
                with open(root + '/' + file, 'rb') as f:
                    all_models.append(pickle.load(f))
            elif file.endswith('.h5'):
                neural_net_weights = os.path.join(root, file)

        for i in all_models:
            if isinstance(i, tf.keras.Model):
                i.load_weights(neural_net_weights)

        with open(os.path.join(directory, 'processor.pkl'), 'rb') as f:
            processor = pickle.load(f)
    return all_models, processor

# %%
bccdc_models, bccdc_processor = read_ml_models(os.path.join(ml_models_dir, bccdc_output_dir))
x500r_models, x500r_processor = read_ml_models(os.path.join(ml_models_dir, x500r_output_dir))

# %%
## Load configurations
model_X = 'SMILES'
bccdc_model_index = 'Name'
x500r_model_index = 'Compound'
bccdc_model_y = 'PTC Confirmed RT'
x500r_model_y = 'Retention Time (min)'

# %%
def create_model_predictions(df, model_df, all_models, processor, database_name=''):
    # Instaniate the Encoder
    vectorizer = train.SMILESVectorizer()
    vectorizer.fit(model_df[model_X].to_list())
    df_vectorized, _ = vectorizer.transform(df[model_X].to_list())

    # Flatten and create feature names
    df_flattened = train.flatten_and_create_feature_names(df_vectorized)

    # Combine with additional features (assuming no additional features in this example)
    combined_df = train.combine_with_additional_features(df_flattened, None)

    # you have the normalized data now
    norm_X = processor.transform(combined_df)

    # Make the predictions
    model_names = config['model_names']
    df_col_names = []
    for i,name in enumerate(model_names):
        df_col_names.append(database_name + name + '_prediction')
        df[database_name + name + '_prediction'] = all_models[i].predict(norm_X)
    return df, df_col_names

# %%
# drop na
bccdc_data.dropna(subset=['SMILES'], inplace=True)

# %%
bccdc_data, bccdc_model_names = create_model_predictions(bccdc_data, bccdc_data, bccdc_models, bccdc_processor)
x500r_data, x500r_model_names = create_model_predictions(x500r_data, x500r_data, x500r_models, x500r_processor)
# Out:
# max_smiles_length: [24, 30, 42, 35, 35, 50, 40, 40, 37, 40, 37, 21, 48, 30, 47, 36, 14, 30, 25, 34, 37, 35, 32, 30, 30, 62, 30, 44, 28, 47, 30, 37, 30, 32, 39, 38, 33, 44, 37, 37, 36, 39, 31, 36, 41, 26, 36, 36, 43, 32, 34, 29, 35, 33, 47, 27, 45, 30, 30, 28, 38, 38, 45, 38, 38, 46, 46, 44, 33, 19, 53, 56, 18, 39, 36, 31, 39, 29, 55, 61, 29, 23, 20, 26, 58, 35, 37, 31, 22, 29, 25, 39, 17, 38, 15, 29, 26, 26, 32, 27, 19, 38, 28, 50, 36, 42, 44, 16, 42, 56, 32, 26, 33, 23, 26, 37, 27, 28, 31, 35, 28, 33, 42, 39, 36, 34, 40, 28, 26, 18, 17, 33, 18, 26, 38, 30, 34, 40, 27, 18, 38, 37, 49, 34, 62, 41, 38, 37, 42, 29, 42, 39, 44, 32, 31, 32, 38, 63, 32, 52, 39, 22, 40, 46, 39, 46, 39]
# Charset Size: 39
# Char to Int Mapping: {'l': 1, 'y': 2, '@': 3, '3': 4, 'H': 5, 'S': 6, 'F': 7, 'C': 8, 'r': 9, 's': 10, '/': 11, 'c': 12, 'o': 13, '+': 14, 'I': 15, '5': 16, '(': 17, '2': 18, ')': 19, '9': 20, 'i': 21, '#': 22, '6': 23, '8': 24, '4': 25, '=': 26, '1': 27, 'O': 28, '[': 29, 'D': 30, 'B': 31, ']': 32, 'N': 33, '7': 34, 'n': 35, '-': 36, '!': 0, 'E': 0, 'UNK': 0}
# 6/6 [==============================] - 0s 2ms/step
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# max_smiles_length: [14, 14, 18, 15, 17, 18, 14, 16, 19, 18, 16, 19, 16, 20, 19, 22, 22, 20, 20, 20, 21, 20, 22, 17, 20, 19, 27, 26, 22, 19, 23, 24, 20, 23, 21, 21, 20, 22, 22, 23, 26, 20, 18, 22, 24, 24, 23, 26, 26, 26, 24, 22, 26, 23, 23, 21, 23, 23, 21, 24, 21, 25, 26, 27, 25, 26, 25, 27, 26, 22, 27, 29, 27, 27, 26, 23, 22, 31, 23, 28, 26, 26, 28, 26, 26, 26, 28, 26, 26, 30, 28, 28, 26, 28, 24, 25, 30, 26, 23, 24, 22, 29, 27, 31, 27, 29, 27, 28, 29, 28, 30, 30, 33, 33, 30, 29, 31, 23, 25, 27, 25, 21, 30, 30, 30, 37, 32, 36, 24, 31, 27, 27, 31, 29, 28, 30, 27, 28, 26, 28, 31, 32, 31, 33, 30, 32, 24, 31, 30, 35, 29, 33, 31, 30, 28, 31, 32, 32, 33, 30, 34, 29, 32, 27, 35, 35, 35, 28, 30, 35, 36, 36, 36, 31, 34, 33, 39, 
38, 51, 25, 31, 35, 37, 44, 48, 50, 38, 45, 38, 40, 35, 44, 40, 39, 23, 40, 27, 51, 43, 48, 43, 50, 46, 42, 45, 22, 43, 43, 47, 47, 38, 44, 37, 35, 46, 34, 42, 50, 41, 56, 54, 40, 41, 33, 37, 53, 54, 50, 53, 24, 51, 20, 49, 37, 47, 19, 24, 26, 32, 28, 24, 24, 39, 46, 48, 26, 26, 37, 38, 40, 29, 26, 31, 23, 31, 27, 33, 48, 36, 34, 38, 58, 37, 45, 28, 33, 42, 18, 43, 44, 25, 19, 18, 43, 45, 28, 30, 27, 19, 23, 43, 42, 24, 29, 43, 48, 50, 38, 39, 44, 31, 26, 47, 48, 48, 50, 15, 34, 39, 15, 36, 13, 33, 19, 11, 44]
# Charset Size: 39
# Char to Int Mapping: {'l': 1, 'y': 2, '@': 3, '3': 4, 'H': 5, 'S': 6, 'F': 7, 'C': 8, 'r': 9, 's': 10, '/': 11, 'c': 12, 'o': 13, '+': 14, 'I': 15, '5': 16, '(': 17, '2': 18, ')': 19, '9': 20, 'i': 21, '#': 22, '6': 23, '8': 24, '4': 25, '=': 26, '1': 27, 'O': 28, '[': 29, 'D': 30, 'B': 31, ']': 32, 'N': 33, '7': 34, 'n': 35, '-': 36, '!': 0, 'E': 0, 'UNK': 0}
# 26/26 [==============================] - 0s 1ms/step
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2

# %%
high_res_data, bccdc_model_names = create_model_predictions(high_res_data, bccdc_data, bccdc_models, bccdc_processor, 'bccdc_')
high_res_data, x500r_model_names = create_model_predictions(high_res_data, x500r_data, x500r_models, x500r_processor, 'X500R_')
# Out:
# max_smiles_length: [24, 30, 42, 35, 35, 50, 40, 40, 37, 40, 37, 21, 48, 30, 47, 36, 14, 30, 25, 34, 37, 35, 32, 30, 30, 62, 30, 44, 28, 47, 30, 37, 30, 32, 39, 38, 33, 44, 37, 37, 36, 39, 31, 36, 41, 26, 36, 36, 43, 32, 34, 29, 35, 33, 47, 27, 45, 30, 30, 28, 38, 38, 45, 38, 38, 46, 46, 44, 33, 19, 53, 56, 18, 39, 36, 31, 39, 29, 55, 61, 29, 23, 20, 26, 58, 35, 37, 31, 22, 29, 25, 39, 17, 38, 15, 29, 26, 26, 32, 27, 19, 38, 28, 50, 36, 42, 44, 16, 42, 56, 32, 26, 33, 23, 26, 37, 27, 28, 31, 35, 28, 33, 42, 39, 36, 34, 40, 28, 26, 18, 17, 33, 18, 26, 38, 30, 34, 40, 27, 18, 38, 37, 49, 34, 62, 41, 38, 37, 42, 29, 42, 39, 44, 32, 31, 32, 38, 63, 32, 52, 39, 22, 40, 46, 39, 46, 39]
# Charset Size: 39
# Char to Int Mapping: {'l': 1, 'y': 2, '@': 3, '3': 4, 'H': 5, 'S': 6, 'F': 7, 'C': 8, 'r': 9, 's': 10, '/': 11, 'c': 12, 'o': 13, '+': 14, 'I': 15, '5': 16, '(': 17, '2': 18, ')': 19, '9': 20, 'i': 21, '#': 22, '6': 23, '8': 24, '4': 25, '=': 26, '1': 27, 'O': 28, '[': 29, 'D': 30, 'B': 31, ']': 32, 'N': 33, '7': 34, 'n': 35, '-': 36, '!': 0, 'E': 0, 'UNK': 0}
# 73/73 [==============================] - 0s 1ms/step
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf
min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2

# %%
high_res_data.head()
# Out:
#                                     Compound         PMF     Pmass   F1mass  \
# 0  (Iso)butyryl-F-fentanyl N-benzyl analogue  C22H27FN2O  355.2180      NaN
# 1     1-(1,3-Diphenylpropan-2-yl)pyrrolidine     C19H23N  266.1903  91.0542
# 2              1-(1-Phenylcyclohexyl)azepane     C18H27N  258.2216      NaN
# 3            1-(1-Phenylcyclohexyl)azetidine     C15H21N  216.1747      NaN
# 4       1-(2,3,4-Trimethoxybenzyl)piperazine  C14H22N2O3  267.1703      NaN
#
#      F2mass   F3mass  F4mass  F5mass  F6mass  F1_n  ...  \
# 0       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 1  117.0699  72.0808     NaN     NaN     NaN   1.0  ...
# 2       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 3       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 4       NaN      NaN     NaN     NaN     NaN   NaN  ...
#
#    bccdc_LGBM_prediction  bccdc_Neural Network_prediction  \
# 0               1.367223                         3.764655
# 1               3.821193                         4.670467
# 2               4.740458                         4.293675
# 3               4.229661                         4.516868
# 4               3.559530                         4.412185
#
#    bccdc_Random Forest_prediction  bccdc_XGBoost_prediction  \
# 0                        4.649347                  4.350983
# 1                        4.724676                  4.833315
# 2                        4.271422                  4.294889
# 3                        4.722217                  4.437869
# 4                        4.537919                  4.304276
#
#    X500R_CatBoost_prediction X500R_Lasso_prediction X500R_LGBM_prediction  \
# 0                   7.813790               8.208798              7.531093
# 1                   6.150524               6.972257              5.298522
# 2                   6.166313               7.609275              4.789313
# 3                   5.087007               5.803316              3.028951
# 4                   5.258948               4.308864              4.546580
#
#   X500R_Neural Network_prediction X500R_Random Forest_prediction  \
# 0                        7.656129                       7.023856
# 1                        6.335971                       6.293439
# 2                        6.326034                       6.108912
# 3                        4.542433                       3.818315
# 4                        4.603775                       5.015550
#
#    X500R_XGBoost_prediction
# 0                  7.628216
# 1                  5.867353
# 2                  6.118053
# 3                  5.051534
# 4                  5.189165
#
# [5 rows x 32 columns]

# %%
from datetime import datetime

current_date = datetime.now().strftime('%Y-%m-%d')

# %%
merged_df = pd.merge(high_res_data, bccdc_data[['SMILES', 'PTC Confirmed RT']], on='SMILES', how='left')
merged_df = pd.merge(merged_df, x500r_data[['SMILES', 'Retention Time (min)']], on='SMILES', how='left')

# %%
merged_df.head()
# Out:
#                                     Compound         PMF     Pmass   F1mass  \
# 0  (Iso)butyryl-F-fentanyl N-benzyl analogue  C22H27FN2O  355.2180      NaN
# 1     1-(1,3-Diphenylpropan-2-yl)pyrrolidine     C19H23N  266.1903  91.0542
# 2              1-(1-Phenylcyclohexyl)azepane     C18H27N  258.2216      NaN
# 3            1-(1-Phenylcyclohexyl)azetidine     C15H21N  216.1747      NaN
# 4       1-(2,3,4-Trimethoxybenzyl)piperazine  C14H22N2O3  267.1703      NaN
#
#      F2mass   F3mass  F4mass  F5mass  F6mass  F1_n  ...  \
# 0       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 1  117.0699  72.0808     NaN     NaN     NaN   1.0  ...
# 2       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 3       NaN      NaN     NaN     NaN     NaN   NaN  ...
# 4       NaN      NaN     NaN     NaN     NaN   NaN  ...
#
#    bccdc_Random Forest_prediction  bccdc_XGBoost_prediction  \
# 0                        4.649347                  4.350983
# 1                        4.724676                  4.833315
# 2                        4.271422                  4.294889
# 3                        4.722217                  4.437869
# 4                        4.537919                  4.304276
#
#    X500R_CatBoost_prediction  X500R_Lasso_prediction  X500R_LGBM_prediction  \
# 0                   7.813790                8.208798               7.531093
# 1                   6.150524                6.972257               5.298522
# 2                   6.166313                7.609275               4.789313
# 3                   5.087007                5.803316               3.028951
# 4                   5.258948                4.308864               4.546580
#
#   X500R_Neural Network_prediction X500R_Random Forest_prediction  \
# 0                        7.656129                       7.023856
# 1                        6.335971                       6.293439
# 2                        6.326034                       6.108912
# 3                        4.542433                       3.818315
# 4                        4.603775                       5.015550
#
#   X500R_XGBoost_prediction PTC Confirmed RT  Retention Time (min)
# 0                 7.628216              NaN                   NaN
# 1                 5.867353              NaN                   NaN
# 2                 6.118053              NaN                   NaN
# 3                 5.051534              NaN                   NaN
# 4                 5.189165              NaN                   NaN
#
# [5 rows x 34 columns]

# %%
merged_df['PTC Confirmed RT'].isnull().sum()
# Out:
# 2240

# %%
merged_df.to_csv('/scratch/st-ashapi01-1/RADD/SMILES_ML_PIPELINE/high_res_prediction_both_models_' + current_date + '.csv', index=False)

# %%
bccdc_data.shape
# Out:
# (167, 32)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def make_error_bins(df, model_names, model_y):
    # Calculate errors
    for model in model_names:
        df[f'{model}_error'] = abs(df[model] - df[model_y])

    # Convert to long format manually
    long_data = []
    for index, row in df.iterrows():
        for model in model_names:
            if model != 'model_y':
                long_data.append({
                    'Compound' : row[model_X],
                    'Actual RT': row[model_y],
                    'model': model,
                    'prediction': row[model],
                    'error': row[f'{model}_error'],
                    'under_over': 'Under' if row[model] < row[model_y] else 'Over'
                })

    df_long = pd.DataFrame(long_data)

    # Function to bin errors
    def bin_errors(error):
        if error <= 1.0:
            return '<= 1.0'
        elif 1.0 < error <= 2.0:
            return '> 1.0 and <= 2.0'
        else:
            return '> 2.0'

    # Apply binning
    df_long['error_bin'] = df_long['error'].apply(bin_errors)
    return df_long

# %%
def error_bin_plots(df_long, output_dir, filename='error_plots.png'):
    # Plotting with seaborn
    plt.figure(figsize=(12, 6))
    sns.countplot(data=df_long, x='model', hue='error_bin')
    plt.title('Error Distribution Across Models')
    plt.xlabel('Model')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.legend(title='Error Bin')
    plt.tight_layout()
    plt.show()
    plt.savefig(os.path.join(output_dir, filename))

# %%
bccdc_only_high_res = merged_df[merged_df['PTC Confirmed RT'].notnull()]

# %%
bccdc_only_high_res.shape
# Out:
# (94, 34)

# %%
high_res_plot_df = make_error_bins(bccdc_only_high_res, bccdc_model_names, bccdc_model_y)
error_bin_plots(high_res_plot_df, 'Figures', 'error_bccdc_on_high_res.png')
# Out:
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# /tmp/ipykernel_2394430/2691008910.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{model}_error'] = abs(df[model] - df[model_y])
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 high_res_plot_df = make_error_bins(bccdc_only_high_res, bccdc_model_names, bccdc_model_y)
# ----> 2 error_bin_plots(high_res_plot_df, 'Figures', 'error_bccdc_on_high_res.png')
#
# Cell In[20], line 12, in error_bin_plots(df_long, output_dir, filename)
#      10 plt.tight_layout()
#      11 plt.show()
# ---> 12 plt.savefig(os.path.join(output_dir, filename))
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1224 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1225 return res
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/figure.py:3388, in Figure.savefig(self, fname, transparent, **kwargs)
#    3386     for ax in self.axes:
#    3387         _recursively_make_axes_transparent(stack, ax)
# -> 3388 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/matplotlib/image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File ~/miniconda3/envs/raddpt2/lib/python3.9/site-packages/PIL/Image.py:2456, in Image.save(self, fp, format, **params)
#    2454         fp = builtins.open(filename, "r+b")
#    2455     else:
# -> 2456         fp = builtins.open(filename, "w+b")
#    2458 try:
#    2459     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/arc/project/st-ashapi01-1/git/afraz96/RADD/workflows/part2_version2/Notebooks/Figures/error_bccdc_on_high_res.png'

# %%
high_res_plot_df
# Out:
#                                            Compound  Actual RT  \
# 0               Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2       4.28
# 1               Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2       4.28
# 2               Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2       4.28
# 3               Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2       4.28
# 4               Nc1ccc2c(c1)C(c1ccccc1Cl)=NCC(=O)N2       4.28
# ..                                              ...        ...
# 559  CN1CCN(C(=O)OC2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1       4.08
# 560  CN1CCN(C(=O)OC2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1       4.08
# 561  CN1CCN(C(=O)OC2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1       4.08
# 562  CN1CCN(C(=O)OC2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1       4.08
# 563  CN1CCN(C(=O)OC2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1       4.08
#
#                                model  prediction     error under_over  \
# 0          bccdc_CatBoost_prediction    4.631853  0.351853       Over
# 1             bccdc_Lasso_prediction    4.539026  0.259026       Over
# 2              bccdc_LGBM_prediction    4.279419  0.000581      Under
# 3    bccdc_Neural Network_prediction    4.421601  0.141601       Over
# 4     bccdc_Random Forest_prediction    4.277031  0.002969      Under
# ..                               ...         ...       ...        ...
# 559           bccdc_Lasso_prediction    4.311009  0.231009       Over
# 560            bccdc_LGBM_prediction    4.075814  0.004186      Under
# 561  bccdc_Neural Network_prediction    4.072472  0.007528      Under
# 562   bccdc_Random Forest_prediction    4.075287  0.004713      Under
# 563         bccdc_XGBoost_prediction    4.264070  0.184070       Over
#
#     error_bin
# 0      <= 1.0
# 1      <= 1.0
# 2      <= 1.0
# 3      <= 1.0
# 4      <= 1.0
# ..        ...
# 559    <= 1.0
# 560    <= 1.0
# 561    <= 1.0
# 562    <= 1.0
# 563    <= 1.0
#
# [564 rows x 7 columns]

# %%
high_res_plot_df.to_csv('temp_results.csv', index=False)
